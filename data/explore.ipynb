# %%
import pandas as pd
df = pd.read_csv('./ME_obsdata16-23.csv')
df
# Out:
#                   datetime  Air_Temperature_celsius  \
# 0      2016-03-21 16:00:00                 6.305704
# 1      2016-03-21 17:00:00                 5.867259
# 2      2016-03-21 18:00:00                 5.427259
# 3      2016-03-21 19:00:00                 4.674370
# 4      2016-03-21 20:00:00                 3.920593
# ...                    ...                      ...
# 66731  2018-11-04 01:00:00                      NaN
# 66732  2019-11-03 01:00:00                      NaN
# 66733  2020-11-01 01:00:00                      NaN
# 66734  2021-11-07 01:00:00                      NaN
# 66735  2022-11-06 01:00:00                      NaN
#
#        Shortwave_Radiation_Downwelling_wattPerMeterSquared  \
# 0                                             288.034637
# 1                                             156.870400
# 2                                              10.915081
# 3                                               0.000000
# ...

# %%
df.isna().sum()
# Out:
# datetime                                               0
# Air_Temperature_celsius                                7
# Shortwave_Radiation_Downwelling_wattPerMeterSquared    7
# Longwave_Radiation_Downwelling_wattPerMeterSquared     7
# Relative_Humidity_percent                              7
# Ten_Meter_Elevation_Wind_Speed_meterPerSecond          7
# Precipitation_millimeterPerDay                         7
# Surface_Level_Barometric_Pressure_pascal               7
# secchi_m                                               0
# tp_ugL                                                 0
# Water_Temp_filled                                      0
# DO_filled                                              0
# poc                                                    4
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#                   datetime  Air_Temperature_celsius  \
# 49399  2021-11-09 04:00:00                 5.685037
# 49400  2021-11-09 05:00:00                 5.168963
# 49401  2021-11-09 06:00:00                 4.648148
# 49402  2021-11-09 07:00:00                 6.011852
# 66729  2016-11-06 01:00:00                      NaN
# 66730  2017-11-05 01:00:00                      NaN
# 66731  2018-11-04 01:00:00                      NaN
# 66732  2019-11-03 01:00:00                      NaN
# 66733  2020-11-01 01:00:00                      NaN
# 66734  2021-11-07 01:00:00                      NaN
# 66735  2022-11-06 01:00:00                      NaN
#
#        Shortwave_Radiation_Downwelling_wattPerMeterSquared  \
# 49399                                           0.000000
# 49400                                           0.000000
# 49401                                           0.000000
# 49402                                          27.348622
# ...

# %%
df = df[:66729]
df
# Out:
#                   datetime  Air_Temperature_celsius  \
# 0      2016-03-21 16:00:00                 6.305704
# 1      2016-03-21 17:00:00                 5.867259
# 2      2016-03-21 18:00:00                 5.427259
# 3      2016-03-21 19:00:00                 4.674370
# 4      2016-03-21 20:00:00                 3.920593
# ...                    ...                      ...
# 66724  2023-11-01 03:00:00                -7.676264
# 66725  2023-11-01 04:00:00                -7.790289
# 66726  2023-11-01 05:00:00                -7.906144
# 66727  2023-11-01 06:00:00                -8.022722
# 66728  2023-11-01 07:00:00                -6.505919
#
#        Shortwave_Radiation_Downwelling_wattPerMeterSquared  \
# 0                                             288.034637
# 1                                             156.870400
# 2                                              10.915081
# 3                                               0.000000
# ...

# %%
df = df.fillna(0.5)
df
# Out:
#                   datetime  Air_Temperature_celsius  \
# 0      2016-03-21 16:00:00                 6.305704
# 1      2016-03-21 17:00:00                 5.867259
# 2      2016-03-21 18:00:00                 5.427259
# 3      2016-03-21 19:00:00                 4.674370
# 4      2016-03-21 20:00:00                 3.920593
# ...                    ...                      ...
# 66724  2023-11-01 03:00:00                -7.676264
# 66725  2023-11-01 04:00:00                -7.790289
# 66726  2023-11-01 05:00:00                -7.906144
# 66727  2023-11-01 06:00:00                -8.022722
# 66728  2023-11-01 07:00:00                -6.505919
#
#        Shortwave_Radiation_Downwelling_wattPerMeterSquared  \
# 0                                             288.034637
# 1                                             156.870400
# 2                                              10.915081
# 3                                               0.000000
# ...

# %%
df.shape
# Out:
# (66729, 13)

# %%
df = df[:3000]
df
# Out:
#                  datetime  Air_Temperature_celsius  \
# 0     2016-03-21 16:00:00                 6.305704
# 1     2016-03-21 17:00:00                 5.867259
# 2     2016-03-21 18:00:00                 5.427259
# 3     2016-03-21 19:00:00                 4.674370
# 4     2016-03-21 20:00:00                 3.920593
# ...                   ...                      ...
# 2995  2016-07-24 11:00:00                31.957630
# 2996  2016-07-24 12:00:00                33.124222
# 2997  2016-07-24 13:00:00                33.526889
# 2998  2016-07-24 14:00:00                33.932741
# 2999  2016-07-24 15:00:00                34.335446
#
#       Shortwave_Radiation_Downwelling_wattPerMeterSquared  \
# 0                                            288.034637
# 1                                            156.870400
# 2                                             10.915081
# 3                                              0.000000
# 4                                              0.000000
# ...

# %%
df.to_csv('../data/mendota_observed.csv', index=False)
